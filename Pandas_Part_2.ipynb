# %% [markdown]
# # Mission 1
#
# Display the following information [for this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user).
# - The last 5 rows
# - The first 5 rows
# - The type of each column
#
# Note : start coding something by typing `pd.read...` and explore the different options available, especially the `sep` parameter.

# %%
import pandas as pd
tb1=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user", sep="|")
tb1.tail() #affiche les 5 dernierers lignes par defaut
# Out:
#        1  24  M     technician  85711
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841

# %%
tb1.head() #affiche les 5 premieres lignes par defaut
# Out:
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
tb1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   1           942 non-null    int64
#  1   24          942 non-null    int64
#  2   M           942 non-null    object
#  3   technician  942 non-null    object
#  4   85711       942 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 36.9+ KB

# %% [markdown]
# # Mission 2
#
# Display the first 10 rows [in the following file](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv)

# %%
import pandas as pd
tb2=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv",sep=",")
tb2.head(10)

# %% [markdown]
# Set the "country" column as the index for the dataframe.

# %%
tb2.set_index("country", inplace = True)
tb2.head()

# %% [markdown]
# # Mission 3
#
# Access the values of the row for **Zimbabwe** (use the index value)

# %%
tb2.loc["Zimbabwe"]#pour afficher par la valeur de la ligne loc ,"iloc" pour afficher par index une ligne tb2.iloc[4]

# %% [markdown]
# # Mision 4
#
# Display only the "continent" column value for the country **Zimbabwe**.

# %%
tb2.loc["Zimbabwe","continent"]

# %% [markdown]
# # Mission 5
#
# Rename the columns [of this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv), try using the following 2 different methods to achieve this:
# - Setting column names directly when reading the file
# - Editing after creating the dataframe ([This resource could be useful](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html))

# %%
import pandas as pd
tb3=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv", sep=",")
tb3
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
tb3.rename(columns={"City":"Villes","Colors Reported":"Couleurs Signalées","Shape Reported":"Forme Signalées","State":"Etats","Time":"Temps"})
# Out:
#                      Villes Couleurs Signalées Forme Signalées Etats  \
# 0                    Ithaca                NaN        TRIANGLE    NY
# 1               Willingboro                NaN           OTHER    NJ
# 2                   Holyoke                NaN            OVAL    CO
# 3                   Abilene                NaN            DISK    KS
# 4      New York Worlds Fair                NaN           LIGHT    NY
# ...                     ...                ...             ...   ...
# 18236            Grant Park                NaN        TRIANGLE    IL
# 18237           Spirit Lake                NaN            DISK    IA
# 18238           Eagle River                NaN             NaN    WI
# 18239           Eagle River                RED           LIGHT    WI
# 18240                  Ybor                NaN            OVAL    FL
#
#                   Temps
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
import pandas as pd
tb3=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv",sep=",")
tb3.columns=["Villes","Couleurs Signalées","Forme Signalées","Etats","Temps"]
tb3
# Out:
#                      Villes Couleurs Signalées Forme Signalées Etats  \
# 0                    Ithaca                NaN        TRIANGLE    NY
# 1               Willingboro                NaN           OTHER    NJ
# 2                   Holyoke                NaN            OVAL    CO
# 3                   Abilene                NaN            DISK    KS
# 4      New York Worlds Fair                NaN           LIGHT    NY
# ...                     ...                ...             ...   ...
# 18236            Grant Park                NaN        TRIANGLE    IL
# 18237           Spirit Lake                NaN            DISK    IA
# 18238           Eagle River                NaN             NaN    WI
# 18239           Eagle River                RED           LIGHT    WI
# 18240                  Ybor                NaN            OVAL    FL
#
#                   Temps
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %% [markdown]
# # Mission 6
#
# Select the first 3 rows and all the columns of the dataframe using iloc

# %%
tb3.iloc[0:3]

# %% [markdown]
# # Mission 7
#
# Achieve the same result as in mission 6 by using loc

# %%
tb3.loc[0:2]
