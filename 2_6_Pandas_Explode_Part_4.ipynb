# %% [markdown]
# <a href="https://colab.research.google.com/github/leadeev/PANDAS/blob/main/2_6_Pandas_Explode_Part_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mission
#
# Still using this dataset: http://bit.ly/imdbratings
# - Which actor is mentioned the most often?

# %%
import pandas as pd

link = 'https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv'
df = pd.read_csv(link)
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df['actors_list']
# Out:
# 0      [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1        [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2      [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3      [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4      [u'John Travolta', u'Uma Thurman', u'Samuel L....
#                              ...
# 974    [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975    [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976    [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977    [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978    [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# Name: actors_list, Length: 979, dtype: object

# %%
df['actors_list'].iloc[0]
# Out:
# "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"

# %%
actors = df['actors_list'].iloc[0]
eval(actors)
# Out:
# ['Tim Robbins', 'Morgan Freeman', 'Bob Gunton']

# %%
def actors(actor):
  return eval(actor)

# %%
df['actors_list'] = df['actors_list'].apply(actors)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-0433b39a9a31> in <module>
# ----> 1 df['actors_list'] = df['actors_list'].apply(actors)
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1097                 # "Callable[[Any], Any]"
# ...

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df['actors_list'].explode()
# Out:
# 0           Tim Robbins
# 0        Morgan Freeman
# 0            Bob Gunton
# 1         Marlon Brando
# 1             Al Pacino
#              ...
# 977    Heather O'Rourke
# 977     Craig T. Nelson
# 978       Charlie Sheen
# 978     Michael Douglas
# 978        Tamara Tunie
# Name: actors_list, Length: 2937, dtype: object

# %%
df_actors = df.explode('actors_list')
df_actors
# Out:
#      star_rating                     title content_rating   genre  duration  \
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 0            9.3  The Shawshank Redemption              R   Crime       142
# 1            9.2             The Godfather              R   Crime       175
# 1            9.2             The Godfather              R   Crime       175
# ..           ...                       ...            ...     ...       ...
# 977          7.4               Poltergeist             PG  Horror       114
# 977          7.4               Poltergeist             PG  Horror       114
# 978          7.4               Wall Street              R   Crime       126
# 978          7.4               Wall Street              R   Crime       126
# 978          7.4               Wall Street              R   Crime       126
#
#           actors_list
# 0         Tim Robbins
# ...

# %%
df_actors['actors_list'].value_counts()
# Out:
# Robert De Niro    18
# Clint Eastwood    14
# Brad Pitt         14
# Tom Hanks         14
# Al Pacino         13
#                   ..
# Güven Kiraç        1
# Sibel Kekilli      1
# Birol Ünel         1
# Akio Ôtsuka        1
# Tamara Tunie       1
# Name: actors_list, Length: 1777, dtype: int64

# %%
df_actors['actors_list'].mode()
# Out:
# 0    Robert De Niro
# dtype: object
